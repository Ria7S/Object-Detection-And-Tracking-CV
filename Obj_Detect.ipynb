# %%
import cv2
import numpy as np
import csv
import time
import matplotlib.pyplot as plt

# %%
pip uninstall opencv-python-headless

# %%
pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in d:\ai_int\obj\lib\site-packages (4.10.0.84)
# Requirement already satisfied: numpy>=1.21.2 in d:\ai_int\obj\lib\site-packages (from opencv-python) (1.26.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
def display_image(frame):
    plt.imshow(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
    plt.axis('off')
    plt.show()

# %%
def get_quadrant(x, y, width, height):
    if x < width / 2 and y < height / 2:
        return 4  
    elif x >= width / 2 and y < height / 2:
        return 3  
    elif x < width / 2 and y >= height / 2:
        return 1 
    else:
        return 2

# %%
def detect_color(hsv_frame, x, y, w, h):
    roi = hsv_frame[y:y+h, x:x+w]
    avg_color_per_row = np.average(roi, axis=0)
    avg_color = np.average(avg_color_per_row, axis=0)
    avg_hue = avg_color[0]

    if 0 <= avg_hue <= 10 or 160 <= avg_hue <= 180:
        return "Red"
    elif 35 <= avg_hue <= 85:
        return "Green"
    elif 100 <= avg_hue <= 130:
        return "Blue"
    elif 20 <= avg_hue <= 30:
        return "Yellow"
    else:
        return "Unknown"

# %%
net = cv2.dnn.readNet("yolov3.weights", "yolov3.cfg")

# %%
layer_names = net.getLayerNames()
output_layers = [layer_names[i - 1] for i in net.getUnconnectedOutLayers()]

# %%
classes = []
with open("coco.names", "r") as f:
    classes = [line.strip() for line in f.readlines()]

# %%
ball_class_id = classes.index("sports ball")

# %%
# Dictionary to track last known quadrant of each ball
ball_quadrants = {}

# %%
events = []

# %%
trackers = []

# %%
#video capture
cap = cv2.VideoCapture("AI Assignment video.mp4")  # Or use 0 for webcam

# %%
with open("events_log.txt", mode="w") as f:
    f.write("Time, Quadrant Number, Ball Colour, Type\n")

    # Loop frames
    while True:
        ret, frame = cap.read()
        if not ret:
            break
        
        height, width, channels = frame.shape
        hsv_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)
        blob = cv2.dnn.blobFromImage(frame, 0.00392, (416, 416), (0, 0, 0), True, crop=False)
        net.setInput(blob)
        outs = net.forward(output_layers)
        timestamp = time.time()  # Current timestamp

        class_ids = []
        confidences = []
        boxes = []

        for out in outs:
            for detection in out:
                scores = detection[5:]
                class_id = np.argmax(scores)
                confidence = scores[class_id]
                if confidence > 0.5 and class_id == ball_class_id:  # Only consider balls
                    center_x = int(detection[0] * width)
                    center_y = int(detection[1] * height)
                    w = int(detection[2] * width)
                    h = int(detection[3] * height)

                    x = int(center_x - w / 2)
                    y = int(center_y - h / 2)

                    boxes.append([x, y, w, h])
                    confidences.append(float(confidence))
                    class_ids.append(class_id)

        indexes = cv2.dnn.NMSBoxes(boxes, confidences, 0.5, 0.4)
        for i in range(len(boxes)):
            if i in indexes:
                x, y, w, h = boxes[i]
                color = detect_color(hsv_frame, x, y, w, h)
                label = f"Ball - {color}"
                cv2.rectangle(frame, (x, y), (x + w, y + h), (0, 255, 0), 2)
                cv2.putText(frame, f"{label}", (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

                center_x, center_y = x + w // 2, y + h // 2
                quadrant = get_quadrant(center_x, center_y, width, height)

                # Tracking entry and exit events
                if (x, y, w, h) in ball_quadrants:
                    last_quadrant = ball_quadrants[(x, y, w, h)]
                    if last_quadrant != quadrant:
                        # exit event for the last quadrant
                        f.write(f"{timestamp}, {last_quadrant}, {color}, Exit\n")
                        # entry event for the new quadrant
                        f.write(f"{timestamp}, {quadrant}, {color}, Entry\n")
                        print(f"Ball {color} exited quadrant {last_quadrant} and entered quadrant {quadrant} at {timestamp:.2f}s")
                else:
                    # initial entry event
                    f.write(f"{timestamp}, {quadrant}, {color}, Entry\n")
                    print(f"Ball {color} entered quadrant {quadrant} at {timestamp:.2f}s")

                # last known quadrant of the ball
                ball_quadrants[(x, y, w, h)] = quadrant

        cv2.imshow("Frame", frame)
        
        key = cv2.waitKey(1)
        if key == 27: 
            break
# Out:
# Ball Yellow entered quadrant 3 at 1720446617.87s
# Ball Yellow entered quadrant 3 at 1720446619.65s
# Ball Yellow entered quadrant 3 at 1720446620.23s
# Ball Yellow entered quadrant 3 at 1720446630.68s
# Ball Yellow entered quadrant 3 at 1720446633.23s
# Ball Green entered quadrant 3 at 1720446633.23s
# Ball Green entered quadrant 3 at 1720446633.98s
# Ball Yellow entered quadrant 3 at 1720446635.18s
# Ball Yellow entered quadrant 3 at 1720446635.83s
# Ball Yellow entered quadrant 3 at 1720446637.85s
# Ball Yellow entered quadrant 3 at 1720446639.12s
# Ball Yellow entered quadrant 3 at 1720446641.10s
# Ball Yellow entered quadrant 3 at 1720446641.72s
# Ball Yellow entered quadrant 3 at 1720446642.42s
# Ball Yellow entered quadrant 3 at 1720446643.07s
# Ball Yellow entered quadrant 3 at 1720446644.50s
# Ball Yellow entered quadrant 3 at 1720446647.79s
# Ball Yellow entered quadrant 3 at 1720446648.50s
# Ball Yellow entered quadrant 3 at 1720446649.82s
# Ball Yellow entered quadrant 3 at 1720446652.97s
# Ball Yellow entered quadrant 3 at 1720446653.57s
# Ball Yellow entered quadrant 3 at 1720446654.27s
# Ball Yellow entered quadrant 3 at 1720446654.97s
# Ball Yellow entered quadrant 3 at 1720446656.37s
# Ball Yellow entered quadrant 3 at 1720446675.51s
# Ball Yellow entered quadrant 3 at 1720446685.53s
# Ball Yellow entered quadrant 3 at 1720446686.23s
# Ball Yellow entered quadrant 3 at 1720446687.00s
# Ball Yellow entered quadrant 3 at 1720446687.88s
# Ball Yellow entered quadrant 3 at 1720446688.76s
# Ball Yellow entered quadrant 3 at 1720446690.38s
# Ball Yellow entered quadrant 3 at 1720446691.15s
# Ball Yellow entered quadrant 3 at 1720446691.76s
# Ball Yellow entered quadrant 3 at 1720446692.39s
# Ball Yellow entered quadrant 3 at 1720446693.03s
# Ball Yellow entered quadrant 3 at 1720446693.64s
# Ball Yellow entered quadrant 3 at 1720446694.98s
# Ball Yellow entered quadrant 3 at 1720446695.60s
# Ball Yellow entered quadrant 3 at 1720446696.91s
# Ball Yellow entered quadrant 3 at 1720446697.58s
# Ball Yellow entered quadrant 3 at 1720446698.32s
# Ball Yellow entered quadrant 3 at 1720446699.67s
# Ball Yellow entered quadrant 3 at 1720446700.34s
# Ball Yellow entered quadrant 3 at 1720446701.07s
# Ball Yellow entered quadrant 3 at 1720446701.76s
# Ball Yellow entered quadrant 3 at 1720446705.56s
# Ball Yellow entered quadrant 3 at 1720446718.21s
# Ball Yellow entered quadrant 3 at 1720446724.29s
# Ball Yellow entered quadrant 3 at 1720446726.94s
# Ball Yellow entered quadrant 3 at 1720446728.63s
# Ball Yellow entered quadrant 3 at 1720446729.57s
# Ball Yellow entered quadrant 3 at 1720446733.21s
# Ball Yellow entered quadrant 3 at 1720446737.84s
# Ball Yellow entered quadrant 3 at 1720446740.58s
# Ball Yellow entered quadrant 3 at 1720446741.53s
# Ball Yellow entered quadrant 3 at 1720446743.35s
# Ball Yellow entered quadrant 3 at 1720446744.28s
# Ball Yellow entered quadrant 3 at 1720446746.11s
# Ball Yellow entered quadrant 3 at 1720446747.92s
# Ball Yellow entered quadrant 3 at 1720446748.87s
# Ball Yellow entered quadrant 3 at 1720446752.67s
# Ball Yellow entered quadrant 3 at 1720446756.94s
# Ball Yellow entered quadrant 1 at 1720446757.89s
# Ball Yellow entered quadrant 1 at 1720446758.89s
# Ball Yellow entered quadrant 3 at 1720446766.30s
# Ball Yellow entered quadrant 3 at 1720446772.32s
# Ball Yellow entered quadrant 3 at 1720446774.28s
# Ball Yellow entered quadrant 3 at 1720446775.30s
# Ball Yellow entered quadrant 3 at 1720446778.38s
# Ball Yellow entered quadrant 3 at 1720446780.36s
# Ball Yellow entered quadrant 3 at 1720446782.51s
# Ball Yellow entered quadrant 3 at 1720446789.57s
# Ball Yellow entered quadrant 3 at 1720446793.41s
# Ball Yellow entered quadrant 3 at 1720446794.37s
# Ball Yellow entered quadrant 3 at 1720446796.75s
# Ball Yellow entered quadrant 3 at 1720446801.78s
# Ball Yellow entered quadrant 3 at 1720446809.61s
# Ball Yellow entered quadrant 3 at 1720446810.88s
# Ball Yellow entered quadrant 3 at 1720446812.96s
# Ball Yellow entered quadrant 3 at 1720446813.88s
# Ball Yellow entered quadrant 3 at 1720446814.84s
# Ball Yellow entered quadrant 3 at 1720446815.77s
# Ball Yellow entered quadrant 3 at 1720446819.82s
# Ball Yellow entered quadrant 3 at 1720446825.12s
# Ball Yellow entered quadrant 3 at 1720446828.08s
# Ball Yellow entered quadrant 3 at 1720446834.23s
# Ball Yellow entered quadrant 3 at 1720446835.47s
# Ball Yellow entered quadrant 3 at 1720446858.26s
# Ball Yellow entered quadrant 3 at 1720446861.11s
# Ball Yellow entered quadrant 3 at 1720446862.93s
# Ball Yellow entered quadrant 3 at 1720446885.14s
# Ball Yellow entered quadrant 3 at 1720446889.20s
# Ball Yellow entered quadrant 2 at 1720447055.82s
# Ball Yellow entered quadrant 2 at 1720447056.74s
# Ball Yellow entered quadrant 2 at 1720447057.68s
# Ball Yellow entered quadrant 2 at 1720447058.56s
# Ball Yellow entered quadrant 2 at 1720447059.42s
# Ball Yellow entered quadrant 2 at 1720447060.27s
# Ball Yellow entered quadrant 2 at 1720447061.13s
# Ball Yellow entered quadrant 2 at 1720447062.07s
# Ball Yellow entered quadrant 2 at 1720447063.01s
# Ball Yellow entered quadrant 2 at 1720447063.93s
# Ball Yellow entered quadrant 2 at 1720447065.75s
# Ball Yellow entered quadrant 2 at 1720447066.63s
# Ball Yellow entered quadrant 2 at 1720447068.43s
# Ball Yellow entered quadrant 2 at 1720447069.29s
# Ball Yellow entered quadrant 2 at 1720447070.14s
# Ball Yellow entered quadrant 2 at 1720447071.11s
# Ball Yellow entered quadrant 2 at 1720447071.97s
# Ball Yellow entered quadrant 2 at 1720447072.84s
# Ball Yellow entered quadrant 2 at 1720447073.71s
# Ball Yellow entered quadrant 2 at 1720447074.59s
# Ball Yellow entered quadrant 2 at 1720447075.44s
# Ball Yellow entered quadrant 2 at 1720447076.33s
# Ball Yellow entered quadrant 2 at 1720447077.30s
# Ball Yellow entered quadrant 2 at 1720447078.14s
# Ball Yellow entered quadrant 2 at 1720447079.11s
# Ball Yellow entered quadrant 2 at 1720447080.00s
# Ball Yellow entered quadrant 2 at 1720447082.96s
# Ball Yellow entered quadrant 2 at 1720447212.67s
# Ball Yellow entered quadrant 2 at 1720447215.08s
# Ball Yellow entered quadrant 2 at 1720447216.11s
# Ball Yellow entered quadrant 2 at 1720447217.02s
# Ball Yellow entered quadrant 2 at 1720447218.01s
# Ball Yellow entered quadrant 2 at 1720447218.87s
# Ball Yellow entered quadrant 2 at 1720447219.83s
# Ball Yellow entered quadrant 2 at 1720447220.72s
# Ball Yellow entered quadrant 2 at 1720447221.60s
# Ball Yellow entered quadrant 2 at 1720447223.42s
# Ball Yellow entered quadrant 2 at 1720447226.14s
# Ball Yellow entered quadrant 2 at 1720447227.08s
# Ball Yellow entered quadrant 2 at 1720447227.97s
# Ball Yellow entered quadrant 2 at 1720447228.89s
# Ball Yellow entered quadrant 2 at 1720447229.78s
# Ball Yellow entered quadrant 2 at 1720447230.75s
# Ball Yellow entered quadrant 2 at 1720447695.31s
# Ball Yellow entered quadrant 2 at 1720447696.29s
# Ball Yellow entered quadrant 2 at 1720447698.06s
# Ball Green entered quadrant 2 at 1720447702.87s
# Ball Yellow entered quadrant 2 at 1720447789.15s
# Ball Yellow entered quadrant 2 at 1720447790.08s
# Ball Yellow entered quadrant 2 at 1720447791.09s
# Ball Yellow entered quadrant 2 at 1720447792.00s
# Ball Yellow entered quadrant 2 at 1720447793.11s
# Ball Yellow entered quadrant 2 at 1720447796.00s
# Ball Yellow entered quadrant 2 at 1720447802.73s
# Ball Yellow entered quadrant 2 at 1720447803.62s
# Ball Yellow entered quadrant 2 at 1720447804.67s
# Ball Yellow entered quadrant 2 at 1720447805.64s
# Ball Yellow entered quadrant 2 at 1720447806.73s
# Ball Yellow entered quadrant 2 at 1720447807.65s
# Ball Yellow entered quadrant 2 at 1720447808.66s
# Ball Yellow entered quadrant 2 at 1720447809.54s
# Ball Yellow entered quadrant 2 at 1720447810.44s
# Ball Yellow entered quadrant 2 at 1720447811.36s
# Ball Yellow entered quadrant 2 at 1720447812.27s
# Ball Yellow entered quadrant 2 at 1720447813.28s
# Ball Yellow entered quadrant 2 at 1720447814.17s
# Ball Yellow entered quadrant 2 at 1720447815.06s
# Ball Yellow entered quadrant 2 at 1720447816.02s
# Ball Yellow entered quadrant 2 at 1720447816.98s
# Ball Yellow entered quadrant 2 at 1720447817.85s
# Ball Yellow entered quadrant 2 at 1720447818.75s
# Ball Yellow entered quadrant 2 at 1720447819.96s
# Ball Yellow entered quadrant 2 at 1720447821.39s
# Ball Yellow entered quadrant 2 at 1720447822.95s
# Ball Yellow entered quadrant 2 at 1720447824.71s
# Ball Yellow entered quadrant 2 at 1720447826.11s
# Ball Yellow entered quadrant 2 at 1720447827.37s
# Ball Yellow entered quadrant 2 at 1720447828.58s
# Ball Yellow entered quadrant 2 at 1720447829.99s
# Ball Yellow entered quadrant 2 at 1720447831.32s
# Ball Yellow entered quadrant 2 at 1720447832.45s
# Ball Yellow entered quadrant 2 at 1720447833.40s
# Ball Yellow entered quadrant 2 at 1720447834.35s
# Ball Yellow entered quadrant 2 at 1720447835.37s
# Ball Yellow entered quadrant 2 at 1720447836.29s
# Ball Yellow entered quadrant 2 at 1720447837.96s
# Ball Yellow entered quadrant 2 at 1720447839.40s
# Ball Yellow entered quadrant 2 at 1720447842.12s
# Ball Yellow entered quadrant 2 at 1720447844.24s
# Ball Yellow entered quadrant 2 at 1720447845.15s
# Ball Yellow entered quadrant 2 at 1720447846.10s
# Ball Yellow entered quadrant 2 at 1720447847.04s
# Ball Yellow entered quadrant 2 at 1720447848.05s
# Ball Yellow entered quadrant 2 at 1720447849.07s
# Ball Green entered quadrant 3 at 1720447854.18s
# Ball Yellow entered quadrant 3 at 1720447880.50s
# Ball Green entered quadrant 3 at 1720447882.68s
# Ball Yellow entered quadrant 2 at 1720447893.14s
# Ball Yellow entered quadrant 2 at 1720447895.14s
# Ball Yellow entered quadrant 2 at 1720447897.14s
# Ball Yellow entered quadrant 2 at 1720447899.20s
# Ball Yellow entered quadrant 2 at 1720447900.29s
# Ball Yellow entered quadrant 2 at 1720447901.52s
# Ball Unknown entered quadrant 2 at 1720447906.90s
# Ball Unknown entered quadrant 2 at 1720447908.01s
# Ball Yellow entered quadrant 2 at 1720447924.88s
# Ball Yellow entered quadrant 2 at 1720447926.57s
# Ball Yellow entered quadrant 2 at 1720447928.05s
# Ball Yellow entered quadrant 2 at 1720447929.81s
# Ball Yellow entered quadrant 2 at 1720447931.29s
# Ball Yellow entered quadrant 2 at 1720447938.34s
# Ball Yellow entered quadrant 2 at 1720447939.31s
# Ball Yellow entered quadrant 2 at 1720447940.39s
# Ball Yellow entered quadrant 2 at 1720447941.25s
# Ball Yellow entered quadrant 2 at 1720447942.11s
# Ball Yellow entered quadrant 2 at 1720447943.96s
# Ball Yellow entered quadrant 2 at 1720447944.82s
# Ball Yellow entered quadrant 2 at 1720447945.71s
# Ball Yellow entered quadrant 2 at 1720447947.79s
# Ball Yellow entered quadrant 2 at 1720447948.63s
# Ball Yellow entered quadrant 2 at 1720447949.52s
# Ball Yellow entered quadrant 2 at 1720447950.37s
# Ball Yellow entered quadrant 2 at 1720447951.22s
# Ball Yellow entered quadrant 2 at 1720447952.98s
# Ball Yellow entered quadrant 2 at 1720447957.59s
# Ball Yellow entered quadrant 2 at 1720447958.50s
# Ball Yellow entered quadrant 2 at 1720447969.81s
# Ball Yellow entered quadrant 2 at 1720447970.66s
# Ball Yellow entered quadrant 2 at 1720447971.64s
# Ball Yellow entered quadrant 2 at 1720447972.55s
# Ball Yellow entered quadrant 2 at 1720447977.90s
# Ball Yellow entered quadrant 2 at 1720447979.08s
# Ball Yellow entered quadrant 2 at 1720447981.17s
# Ball Yellow entered quadrant 2 at 1720447984.94s
# Ball Yellow entered quadrant 2 at 1720447985.80s
# Ball Yellow entered quadrant 2 at 1720447986.74s
# Ball Yellow entered quadrant 2 at 1720447989.55s
# Ball Yellow entered quadrant 2 at 1720447990.44s
# Ball Yellow entered quadrant 2 at 1720447991.36s
# Ball Yellow entered quadrant 2 at 1720447994.17s
# Ball Yellow entered quadrant 2 at 1720447995.08s
# Ball Yellow entered quadrant 2 at 1720447995.98s
# Ball Yellow entered quadrant 2 at 1720447996.87s
# Ball Yellow entered quadrant 2 at 1720447999.78s
# Ball Yellow entered quadrant 2 at 1720448001.97s
# Ball Yellow entered quadrant 2 at 1720448004.02s
# Ball Yellow entered quadrant 2 at 1720448006.44s
# Ball Yellow entered quadrant 2 at 1720448009.28s
# Ball Yellow entered quadrant 2 at 1720448010.56s
# Ball Yellow entered quadrant 2 at 1720448013.79s
# Ball Yellow entered quadrant 2 at 1720448020.43s
# Ball Yellow entered quadrant 2 at 1720448024.91s
# Ball Yellow entered quadrant 2 at 1720448025.84s
# Ball Yellow entered quadrant 2 at 1720448026.72s
# Ball Yellow entered quadrant 2 at 1720448027.61s
# Ball Yellow entered quadrant 2 at 1720448028.56s
# Ball Yellow entered quadrant 2 at 1720448031.30s
# Ball Yellow entered quadrant 2 at 1720448034.85s
# Ball Yellow entered quadrant 2 at 1720448035.74s
# Ball Yellow entered quadrant 2 at 1720448036.61s
# Ball Yellow entered quadrant 2 at 1720448037.52s
# Ball Yellow entered quadrant 2 at 1720448040.29s
# Ball Yellow entered quadrant 2 at 1720448046.03s
# Ball Yellow entered quadrant 2 at 1720448047.28s
# Ball Yellow entered quadrant 2 at 1720448048.37s
# Ball Yellow entered quadrant 2 at 1720448052.37s
# Ball Yellow entered quadrant 2 at 1720448055.10s

# %%
cap.release()
cv2.destroyAllWindows()
